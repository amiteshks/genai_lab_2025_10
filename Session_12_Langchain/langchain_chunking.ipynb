# %%
# %pip install langchain langchain-community pypdf langchain-text-splitters

# %%
from langchain_community.document_loaders import PyPDFLoader

file_path = "data/claim.pdf"
loader = PyPDFLoader(file_path)
docs = loader.load()
print(f"Loaded {len(docs)} pages.")
# Out:
# Loaded 2 pages.

# %%
# %pip install langchain-text-splitters
from langchain_text_splitters import RecursiveCharacterTextSplitter
# from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=100,
    separators=["\n\n", "\n", ".", " ", ""],
)
# Out:
# Requirement already satisfied: langchain-text-splitters in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langchain-text-splitters) (1.1.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.42)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.12.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: anyio in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (4.11.0)
# Requirement already satisfied: certifi in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/amiteshsinha/Training/10_2025_genai_lab/.venv/lib/python3.13/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.0->langchain-text-splitters) (1.3.1)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Split the documents
chunks = text_splitter.split_documents(docs)
print(f"Created {len(chunks)} chunks.")

# Inspect the first few chunks
for i, chunk in enumerate(chunks):
    print(f"\n--- Chunk {i+1} ---")
    print(chunk.page_content[:400])  # preview first 400 characters
    print("\nMetadata:", chunk.metadata)
# Out:
# Created 9 chunks.
#
# --- Chunk 1 ---
# ■ MOTOR VEHICLE INSURANCE CLAIM – Case File #MV-2025-1049
# Policyholder: Michael R. Adams
# Address: 782 Elmwood Avenue, San Jose, CA 95126
# Policy Number: CA-892174-AUTO-2024
# Insurer: MetroSure Insurance Company
# Date of Loss: March 15, 2025
# Claim Number: CL-2025-1049
# SECTION 1 – Summary of Incident
# On March 15, 2025, at approximately 6:45 PM, the insured vehicle — a 2022 Tesla Model Y Long
#
# Metadata: {'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-10-14T21:10:41+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2025-10-14T21:10:41+00:00', 'subject': '(unspecified)', 'title': 'Motor Vehicle Insurance Claim – Case File #MV-2025-1049', 'trapped': '/False', 'source': 'data/claim.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
#
# --- Chunk 2 ---
# On March 15, 2025, at approximately 6:45 PM, the insured vehicle — a 2022 Tesla Model Y Long
# Range — was involved in a rear-end collision on US-101 Northbound near Exit 388 (San Mateo
# Bridge). The accident occurred during heavy rain and low visibility conditions. Michael Adams reports
# being stationary in traffic when struck from behind by another vehicle (a 2018 Toyota Camry, driven by
#
# Metadata: {'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-10-14T21:10:41+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2025-10-14T21:10:41+00:00', 'subject': '(unspecified)', 'title': 'Motor Vehicle Insurance Claim – Case File #MV-2025-1049', 'trapped': '/False', 'source': 'data/claim.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
#
# --- Chunk 3 ---
# Lydia Cho). CHP attributed fault to Ms. Cho for following too closely.
# SECTION 2 – Damage Assessment
# Inspection on March 18, 2025, by AutoSure Adjusters Inc. Damage includes cracked rear bumper,
# deformed crumple zone, misaligned trunk, damaged radar module, and shattered tail light assembly.
# Estimated repair cost: $9,875.43 (Precision AutoWorks, San Jose).
# SECTION 3 – Policy Coverage Analysis
#
# Metadata: {'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-10-14T21:10:41+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2025-10-14T21:10:41+00:00', 'subject': '(unspecified)', 'title': 'Motor Vehicle Insurance Claim – Case File #MV-2025-1049', 'trapped': '/False', 'source': 'data/claim.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
#
# --- Chunk 4 ---
# SECTION 3 – Policy Coverage Analysis
# Policy CA-892174-AUTO-2024 provides coverage: Collision ($1,000 deductible), Property Damage
# Liability ($50,000), Bodily Injury ($100,000 per person), and Rental Reimbursement ($40/day, 30 days
# max).
# SECTION 4 – Medical & Bodily Injury Evaluation
# Insured reported minor neck strain. Total medical expenses $1,842.00, expected to be subrogated from
#
# Metadata: {'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-10-14T21:10:41+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2025-10-14T21:10:41+00:00', 'subject': '(unspecified)', 'title': 'Motor Vehicle Insurance Claim – Case File #MV-2025-1049', 'trapped': '/False', 'source': 'data/claim.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
#
# --- Chunk 5 ---
# at-fault driver’s insurer (Highway Mutual Insurance).
# SECTION 5 – Subrogation and Liability Discussion
# Primary fault assigned to Ms. Cho; comparative negligence of 10% on insured due to delayed braking
# (0.7s delay). MetroSure to recover 90% of damages under inter-insurer agreement dated April 2, 2025.
# SECTION 6 – Rental Vehicle Authorization
#
# Metadata: {'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-10-14T21:10:41+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2025-10-14T21:10:41+00:00', 'subject': '(unspecified)', 'title': 'Motor Vehicle Insurance Claim – Case File #MV-2025-1049', 'trapped': '/False', 'source': 'data/claim.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
#
# --- Chunk 6 ---
# SECTION 6 – Rental Vehicle Authorization
# Rental authorized through Enterprise from March 17, 2025, for 12 days at $38.50/day. Reimbursement
# total $462.00.
#
# Metadata: {'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-10-14T21:10:41+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2025-10-14T21:10:41+00:00', 'subject': '(unspecified)', 'title': 'Motor Vehicle Insurance Claim – Case File #MV-2025-1049', 'trapped': '/False', 'source': 'data/claim.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}
#
# --- Chunk 7 ---
# SECTION 7 – Payment and Settlement Summary
# Repair: $9,875.43, Medical: $1,842.00, Rental: $462.00, less deductible $1,000. Total payout
# $11,179.43 issued April 10, 2025.
# SECTION 8 – Dispute and Reinvestigation
# Dispute filed May 2, 2025, contesting 10% comparative negligence. Supplemental review (Case ID:
# SR-2025-06) pending arbitration decision.
# SECTION 9 – Notes and Internal Comments
#
# Metadata: {'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-10-14T21:10:41+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2025-10-14T21:10:41+00:00', 'subject': '(unspecified)', 'title': 'Motor Vehicle Insurance Claim – Case File #MV-2025-1049', 'trapped': '/False', 'source': 'data/claim.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}
#
# --- Chunk 8 ---
# SR-2025-06) pending arbitration decision.
# SECTION 9 – Notes and Internal Comments
# Adjuster: Emily Tran, Supervisor review April 15, 2025. Claim reopened for review; evidence
# inconclusive due to visibility issues.
# SECTION 10 – Policy References
# Key clauses: §4.1 Collision Coverage, §5.2 Comparative Negligence, §7.2 Temporary Transportation.
# ATTACHMENT A – Damage Cost Breakdown
# Item
# Description
#
# Metadata: {'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-10-14T21:10:41+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2025-10-14T21:10:41+00:00', 'subject': '(unspecified)', 'title': 'Motor Vehicle Insurance Claim – Case File #MV-2025-1049', 'trapped': '/False', 'source': 'data/claim.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}
#
# --- Chunk 9 ---
# ATTACHMENT A – Damage Cost Breakdown
# Item
# Description
# Estimated Cost ($)
# Rear Bumper
# Cracked and detached
# 1,200.00
# Radar Module
# Water intrusion
# 850.00
# Trunk Alignment
# Off-center, needs realignment
# 1,100.00
# Tail Light Assembly
# Shattered
# 700.00
# Paint Damage
# Rear quarter panel, liftgate
# 450.00
#
# Metadata: {'producer': 'ReportLab PDF Library - www.reportlab.com', 'creator': '(unspecified)', 'creationdate': '2025-10-14T21:10:41+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2025-10-14T21:10:41+00:00', 'subject': '(unspecified)', 'title': 'Motor Vehicle Insurance Claim – Case File #MV-2025-1049', 'trapped': '/False', 'source': 'data/claim.pdf', 'total_pages': 2, 'page': 1, 'page_label': '2'}
